# %% [markdown]
# Broadcasting in python with help of numpy

# %% [markdown]
# The art of not copyig data

# %% [markdown]
# Cnetering array technique

# %%
import numpy as np

# %%
x = np.array([[10],
             [20],
             [30]])

# %%
x
# Out:
# array([[10],
#        [20],
#        [30]])

# %%
m = np.arange(1, 4)

# %%
m
# Out:
# array([1, 2, 3])

# %%
m.shape
# Out:
# (3,)

# %%
m.reshape(1,3)
# Out:
# array([[1, 2, 3]])

# %%
x+m
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])
