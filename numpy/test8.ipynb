# %%
import numpy as np

# %%
np.random.seed(42)
x = np.random.rand(5, 10)

# %%
w = np.random.rand(20,10)
w_t = w.T

# %%
b = np.random.rand(20,)

# %%
z = (x @ w_t) +b

# %%
z.shape
# Out:
# (5, 20)
