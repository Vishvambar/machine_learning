# %%
emp = {"name" : "vishvambar" , "class" : "SY-22" , "Enrollment no" : "ADT25SOCBD089"}
print(type(emp))
# Out:
# <class 'dict'>

# %%
emp['name']
# Out:
# 'vishvambar'

# %%
emp['class']
# Out:
# 'SY-22'

# %%
emp['Enrollment no']
# Out:
# 'ADT25SOCBD089'

# %%
person= {'firstname ' : 'vishvambar' ,'middlename' : 'Ramesh' , 'lastname' : 'Udavant' , 'age' : 20}

# %%
print(person['firstname '])
# Out:
# vishvambar

# %%
person={'firstname': ['Namrata' , 'vishvambar' ,'sakshi'] , 'college' : 'GPJ', 'salary': [100000, 200000, 300000]}

# %%
person
# Out:
# {'firstname': ['Namrata', 'vishvambar', 'sakshi'],
#  'college': 'GPJ',
#  'salary': [100000, 200000, 300000]}

# %%
person['firstname']
# Out:
# ['Namrata', 'vishvambar', 'sakshi']

# %%
person['college']
# Out:
# 'GPJ'

# %%
person['salary']
# Out:
# [100000, 200000, 300000]

# %%
person['firstname'][1]
# Out:
# 'vishvambar'

# %%
person['salary'][2]
# Out:
# 300000

# %%
person['firstname'][1]= 'Namrata Udavant'

# %%
person
# Out:
# {'firstname': ['Namrata', 'Namrata Udavant', 'sakshi'],
#  'college': 'GPJ',
#  'salary': [100000, 200000, 300000]}

# %%
person['firstname'].append('John')

# %%
person
# Out:
# {'firstname': ['Namrata', 'Namrata Udavant', 'sakshi', 'John'],
#  'college': 'GPJ',
#  'salary': [100000, 200000, 300000]}

# %%
del(person['firstname'][2])

# %%
person
# Out:
# {'firstname': ['Namrata', 'Namrata Udavant', 'John'],
#  'college': 'GPJ',
#  'salary': [100000, 200000, 300000]}

# %%
person.keys()
# Out:
# dict_keys(['firstname', 'college', 'salary'])

# %%
person.values()
# Out:
# dict_values([['Namrata', 'Namrata Udavant', 'John'], 'GPJ', [100000, 200000, 300000]])
