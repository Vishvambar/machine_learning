# %%
import numpy as np

# %%
rng = np.random.default_rng(seed=1701)
x1 = rng.integers(10, size = 6)
x2 = rng.integers(10, size = (3,4))
x3 = rng.integers(10, size=(3,4,5))

# %%
x1
# Out:
# array([9, 4, 0, 3, 8, 6])

# %%
x2
# Out:
# array([[3, 1, 3, 7],
#        [4, 0, 2, 3],
#        [0, 0, 6, 9]])

# %%
x3
# Out:
# array([[[4, 3, 5, 5, 0],
#         [8, 3, 5, 2, 2],
#         [1, 8, 8, 5, 3],
#         [0, 0, 8, 5, 8]],
#
#        [[5, 1, 6, 2, 3],
#         [1, 2, 5, 6, 2],
#         [5, 2, 7, 9, 3],
#         [5, 6, 0, 2, 0]],
#
#        [[2, 9, 4, 3, 9],
#         [9, 2, 2, 4, 0],
#         [0, 3, 0, 0, 2],
#         [3, 2, 7, 4, 7]]])

# %%
print(x3.ndim)
# Out:
# 3

# %%
print(x3.shape)
# Out:
# (3, 4, 5)

# %%
print(x3.size)
# Out:
# 60

# %%
print(x3.dtype)
# Out:
# int64

# %% [markdown]
# Array Indexing

# %%
x1[0]
# Out:
# np.int64(9)

# %%
print(x1[0])
# Out:
# 9

# %%
print(x1[-1])
# Out:
# 6

# %%
print(x2[1,2])
# Out:
# 2

# %%
grid = np.arange(1,10).reshape(3,3)
print(grid)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
x = np.array([2,3,5])

# %%
x
# Out:
# array([2, 3, 5])

# %%
x.reshape(1,3)
# Out:
# array([[2, 3, 5]])

# %%
x.reshape(3,1)
# Out:
# array([[2],
#        [3],
#        [5]])

# %%
x
# Out:
# array([2, 3, 5])

# %%
x = np.array([1,2,3])

# %%
y = np.array([4,5,6])

# %%
np.concatenate([x,y])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
z = np.array([7,5,3])

# %%
np.concatenate([x,y,z])
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 5, 3])

# %%
m = np.random.randint(0,10, size=(3,4))

# %%
m
# Out:
# array([[1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8]], dtype=int32)

# %%
n= np.random.randint(1,10,size=(3,4))

# %%
n
# Out:
# array([[3, 1, 2, 1],
#        [2, 4, 8, 3],
#        [4, 6, 9, 4]], dtype=int32)

# %%
np.concatenate([m,n])
# Out:
# array([[1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8],
#        [3, 1, 2, 1],
#        [2, 4, 8, 3],
#        [4, 6, 9, 4]], dtype=int32)

# %%
np.concatenate([m,m])
# Out:
# array([[1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8],
#        [1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8]], dtype=int32)

# %%
np.concatenate([m,m],axis=1)
# Out:
# array([[1, 1, 9, 1, 1, 1, 9, 1],
#        [7, 9, 3, 5, 7, 9, 3, 5],
#        [3, 7, 4, 8, 3, 7, 4, 8]], dtype=int32)

# %%
np.concatenate([m,m],axis=0)x
# Out:
# array([[1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8],
#        [1, 1, 9, 1],
#        [7, 9, 3, 5],
#        [3, 7, 4, 8]], dtype=int32)

# %%
x
# Out:
# array([1, 2, 3])

# %%
p = np.random.randint(1,10,size=(3,3))

# %%
p
# Out:
# array([[8, 5, 7],
#        [1, 4, 4],
#        [5, 1, 4]], dtype=int32)

# %%
np.vstack([x,p])
# Out:
# array([[1, 2, 3],
#        [8, 5, 7],
#        [1, 4, 4],
#        [5, 1, 4]])

# %%
x = np.array([1,2,3,99,99,4,5,6])

# %%
x
# Out:
# array([ 1,  2,  3, 99, 99,  4,  5,  6])

# %%
x1,x2,x3 = np.split(x,[3,5])

# %%
print(x1,x2,x3)
# Out:
# [1 2 3] [99 99] [4 5 6]
