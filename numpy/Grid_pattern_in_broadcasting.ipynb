# %% [markdown]
# Grid pattern in broadcasting

# %%
import numpy as np 
import sys
import matplotlib.pyplot as plt 
np.set_printoptions(threshold=sys.maxsize)

# %%
x = np.random.rand(100)

# %%
x
# Out:
# array([0.17857073, 0.91141666, 0.66768   , 0.258787  , 0.04314255,
#        0.09882153, 0.29510944, 0.74234014, 0.20690011, 0.18534909,
#        0.11668446, 0.7436578 , 0.86358744, 0.59102812, 0.49500356,
#        0.58730193, 0.55567405, 0.20427747, 0.69181865, 0.66588499,
#        0.0638256 , 0.95108205, 0.95250069, 0.96414282, 0.33653131,
#        0.10245351, 0.66109773, 0.81230454, 0.18632624, 0.50256827,
#        0.00706734, 0.11547679, 0.59336437, 0.95040281, 0.08588695,
#        0.44331531, 0.42496561, 0.39063232, 0.94205278, 0.95263002,
#        0.9972851 , 0.67294268, 0.40859249, 0.55443407, 0.40362934,
#        0.16556146, 0.38227825, 0.11477535, 0.51482141, 0.28115731,
#        0.36683654, 0.24280692, 0.78336145, 0.85491766, 0.7371169 ,
#        0.55517199, 0.16224682, 0.38505958, 0.00656451, 0.77877273,
#        0.16302044, 0.34368497, 0.40306827, 0.38294197, 0.41956908,
#        0.73491706, 0.4643613 , 0.65723471, 0.58630685, 0.73585794,
# ...

# %%
x.shape
# Out:
# (100,)

# %%
y = np.random.rand(100)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0.2887612 , 0.22793416, 0.60935111, 0.19802037, 0.13820781,
#        0.6456208 , 0.08374627, 0.60895476, 0.73873897, 0.11181326,
#        0.59962939, 0.34900235, 0.8119405 , 0.8341947 , 0.55432886,
#        0.74593606, 0.22663786, 0.01693334, 0.69902127, 0.71917501,
#        0.84696907, 0.70492775, 0.91659894, 0.07425298, 0.36184672,
#        0.40471608, 0.34249954, 0.56202927, 0.41121541, 0.80518042,
#        0.3915594 , 0.65595889, 0.39734289, 0.2484091 , 0.17377088,
#        0.37787138, 0.42394087, 0.29122707, 0.99041286, 0.25208405,
#        0.63332711, 0.58823751, 0.11357239, 0.61910051, 0.9788649 ,
#        0.68114065, 0.71149561, 0.13258977, 0.10579379, 0.74145503,
#        0.79331284, 0.3819255 , 0.38662188, 0.63801679, 0.8998767 ,
#        0.04060291, 0.54793054, 0.05151237, 0.74234372, 0.46692544,
#        0.29180299, 0.25628073, 0.88029506, 0.13848317, 0.11044085,
#        0.71977734, 0.65194742, 0.62585914, 0.09450032, 0.81420189,
# ...

# %%
x =x.reshape(100,1)

# %%
y =y.reshape(1, 100)

# %%
y
# Out:
# array([[0.2887612 , 0.22793416, 0.60935111, 0.19802037, 0.13820781,
#         0.6456208 , 0.08374627, 0.60895476, 0.73873897, 0.11181326,
#         0.59962939, 0.34900235, 0.8119405 , 0.8341947 , 0.55432886,
#         0.74593606, 0.22663786, 0.01693334, 0.69902127, 0.71917501,
#         0.84696907, 0.70492775, 0.91659894, 0.07425298, 0.36184672,
#         0.40471608, 0.34249954, 0.56202927, 0.41121541, 0.80518042,
#         0.3915594 , 0.65595889, 0.39734289, 0.2484091 , 0.17377088,
#         0.37787138, 0.42394087, 0.29122707, 0.99041286, 0.25208405,
#         0.63332711, 0.58823751, 0.11357239, 0.61910051, 0.9788649 ,
#         0.68114065, 0.71149561, 0.13258977, 0.10579379, 0.74145503,
#         0.79331284, 0.3819255 , 0.38662188, 0.63801679, 0.8998767 ,
#         0.04060291, 0.54793054, 0.05151237, 0.74234372, 0.46692544,
#         0.29180299, 0.25628073, 0.88029506, 0.13848317, 0.11044085,
#         0.71977734, 0.65194742, 0.62585914, 0.09450032, 0.81420189,
# ...

# %%
x
# Out:
# array([[0.17857073],
#        [0.91141666],
#        [0.66768   ],
#        [0.258787  ],
#        [0.04314255],
#        [0.09882153],
#        [0.29510944],
#        [0.74234014],
#        [0.20690011],
#        [0.18534909],
#        [0.11668446],
#        [0.7436578 ],
#        [0.86358744],
#        [0.59102812],
#        [0.49500356],
#        [0.58730193],
#        [0.55567405],
#        [0.20427747],
#        [0.69181865],
#        [0.66588499],
#        [0.0638256 ],
#        [0.95108205],
#        [0.95250069],
#        [0.96414282],
#        [0.33653131],
#        [0.10245351],
#        [0.66109773],
#        [0.81230454],
#        [0.18632624],
#        [0.50256827],
#        [0.00706734],
#        [0.11547679],
#        [0.59336437],
#        [0.95040281],
#        [0.08588695],
#        [0.44331531],
#        [0.42496561],
#        [0.39063232],
#        [0.94205278],
#        [0.95263002],
#        [0.9972851 ],
#        [0.67294268],
#        [0.40859249],
# ...

# %%
m = x+y

# %%
m
# Out:
# array([[0.46733193, 0.40650488, 0.78792184, 0.3765911 , 0.31677853,
#         0.82419152, 0.26231699, 0.78752549, 0.9173097 , 0.29038398,
#         0.77820011, 0.52757308, 0.99051123, 1.01276543, 0.73289958,
#         0.92450678, 0.40520859, 0.19550407, 0.87759199, 0.89774573,
#         1.02553979, 0.88349848, 1.09516966, 0.2528237 , 0.54041745,
#         0.5832868 , 0.52107027, 0.74059999, 0.58978613, 0.98375115,
#         0.57013013, 0.83452961, 0.57591362, 0.42697982, 0.35234161,
#         0.55644211, 0.60251159, 0.4697978 , 1.16898359, 0.43065477,
#         0.81189784, 0.76680824, 0.29214311, 0.79767124, 1.15743562,
#         0.85971137, 0.89006634, 0.31116049, 0.28436451, 0.92002575,
#         0.97188356, 0.56049622, 0.56519261, 0.81658752, 1.07844742,
#         0.21917364, 0.72650127, 0.23008309, 0.92091445, 0.64549617,
#         0.47037371, 0.43485146, 1.05886579, 0.3170539 , 0.28901157,
#         0.89834807, 0.83051814, 0.80442987, 0.27307104, 0.99277261,
# ...

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(np.broadcast_to(x, (100, 100)), cmap='viridis')
ax[0].set_title('X (Vertical Input)\nValues change Top-to-Bottom')
ax[1].imshow(np.broadcast_to(y, (100, 100)), cmap='viridis')
ax[1].set_title('Y (Horizontal Input)\nValues change Left-to-Right')
ax[2].imshow(x + y, cmap='viridis')
ax[2].set_title('X + Y\nThe Gradient Grid')
plt.tight_layout()
plt.show()

# %%
x = np.array([1, 2, 3])

# %%
y = np.array([5])

# %%
x.shape
# Out:
# (3,)

# %%
y.shape
# Out:
# (1,)

# %%
x+y
# Out:
# array([6, 7, 8])
