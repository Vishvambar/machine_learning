# %%
import numpy as np 
import pandas as pd

# %%
data = np.random.randint(60,120 , (5,3))

# %%
df = pd.DataFrame(data , 
                  columns = ["BP", "HR", "Temp"],
                  index = ["A1", "A2", "A3", "B1", "B2"])

# %%
df
# Out:
#     BP   HR  Temp
# A1  74   60    92
# A2  95  103    69
# A3  90   64   114
# B1  87   75    73
# B2  66   84   103

# %%
# HR of B1 
print(df.loc["B1", "HR"])
# Out:
# 75

# %%
print (df.iloc[-1])
# Out:
# BP       66
# HR       84
# Temp    103
# Name: B2, dtype: int32

# %%
warda_index = df.index.str.startswith("A")

# %%
warda = df[warda_index]
warda
# Out:
#     BP   HR  Temp
# A1  74   60    92
# A2  95  103    69
# A3  90   64   114

# %%
critical = warda[warda["HR"]>100]

# %%
critical["BP"]
# Out:
# A2    95
# Name: BP, dtype: int32
