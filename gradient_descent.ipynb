# %%
input = 10
weight = 0.5 
target = 20 
learning_rate = 0.01

# %%
print(f"Start: Input={input }, Weight={weight}, Prediction={input * weight}")
# Out:
# Start: Input=10, Weight=0.5, Prediction=5.0

# %%
for i in range(20):
    prediction = input * weight 
    error = prediction - target 
    slope = error * input 
    weight = weight - (slope * learning_rate)
    print(f"Iter {i+1}: Prediction={prediction:.2f} | Error={error:.2f} | New Weight={weight:.2f}")

print (f"Final Weight : {weight:.2f}")
# Out:
# Iter 1: Prediction=5.00 | Error=-15.00 | New Weight=2.00
# Iter 2: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 3: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 4: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 5: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 6: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 7: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 8: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 9: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 10: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 11: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 12: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 13: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 14: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 15: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 16: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 17: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 18: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 19: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Iter 20: Prediction=20.00 | Error=0.00 | New Weight=2.00
# Final Weight : 2.00

# %%
input_data = 10
target_answer = 20
weight = 0.5 
learning_rate = 0.01 

# We start with a massive error just to get into the loop
error = 100 
iteration = 0

# LOOP UNTIL ERROR IS TINY (Close to 0)
# abs(error) removes the negative sign
while abs(error) > 0.001: 
    iteration += 1
    
    prediction = input_data * weight
    error = prediction - target_answer
    
    slope = error * input_data
    weight = weight - (slope * learning_rate)
    
    print(f"Iter {iteration}: Prediction= {prediction:.4f} Weight={weight:.4f}, Error={error:.4f}")
    
    # Safety break: Stop if it takes too long
    if iteration > 1000:
        print("Took too long! Stopping.")
        break

print(f"Done! It took {iteration} steps to learn.")
# Out:
# Iter 1: Prediction= 5.0000 Weight=2.0000, Error=-15.0000
# Iter 2: Prediction= 20.0000 Weight=2.0000, Error=0.0000
# Done! It took 2 steps to learn.

# %%
input_data = 10
target_answer = 20
weight = 0.5 
learning_rate = 0.001 

# We start with a massive error just to get into the loop
error = 100 
iteration = 0

# LOOP UNTIL ERROR IS TINY (Close to 0)
# abs(error) removes the negative sign
while abs(error) > 0.00001: 
    iteration += 1
    
    prediction = input_data * weight
    error = prediction - target_answer
    
    slope = error * input_data
    weight = weight - (slope * learning_rate)
    
    print(f"Iter {iteration}: Prediction : {prediction:.4f}, Weight={weight:.4f}, Error={error:.4f}")
    
    # Safety break: Stop if it takes too long
    if iteration > 1000:
        print("Took too long! Stopping.")
        break

print(f"Done! It took {iteration} steps to learn.")
# Out:
# Iter 1: Prediction : 5.0000, Weight=0.6500, Error=-15.0000
# Iter 2: Prediction : 6.5000, Weight=0.7850, Error=-13.5000
# Iter 3: Prediction : 7.8500, Weight=0.9065, Error=-12.1500
# Iter 4: Prediction : 9.0650, Weight=1.0158, Error=-10.9350
# Iter 5: Prediction : 10.1585, Weight=1.1143, Error=-9.8415
# Iter 6: Prediction : 11.1426, Weight=1.2028, Error=-8.8574
# Iter 7: Prediction : 12.0284, Weight=1.2826, Error=-7.9716
# Iter 8: Prediction : 12.8255, Weight=1.3543, Error=-7.1745
# Iter 9: Prediction : 13.5430, Weight=1.4189, Error=-6.4570
# Iter 10: Prediction : 14.1887, Weight=1.4770, Error=-5.8113
# Iter 11: Prediction : 14.7698, Weight=1.5293, Error=-5.2302
# Iter 12: Prediction : 15.2928, Weight=1.5764, Error=-4.7072
# Iter 13: Prediction : 15.7636, Weight=1.6187, Error=-4.2364
# Iter 14: Prediction : 16.1872, Weight=1.6568, Error=-3.8128
# Iter 15: Prediction : 16.5685, Weight=1.6912, Error=-3.4315
# Iter 16: Prediction : 16.9116, Weight=1.7220, Error=-3.0884
# Iter 17: Prediction : 17.2205, Weight=1.7498, Error=-2.7795
# Iter 18: Prediction : 17.4984, Weight=1.7749, Error=-2.5016
# Iter 19: Prediction : 17.7486, Weight=1.7974, Error=-2.2514
# Iter 20: Prediction : 17.9737, Weight=1.8176, Error=-2.0263
# Iter 21: Prediction : 18.1764, Weight=1.8359, Error=-1.8236
# Iter 22: Prediction : 18.3587, Weight=1.8523, Error=-1.6413
# Iter 23: Prediction : 18.5228, Weight=1.8671, Error=-1.4772
# Iter 24: Prediction : 18.6706, Weight=1.8804, Error=-1.3294
# Iter 25: Prediction : 18.8035, Weight=1.8923, Error=-1.1965
# Iter 26: Prediction : 18.9232, Weight=1.9031, Error=-1.0768
# Iter 27: Prediction : 19.0308, Weight=1.9128, Error=-0.9692
# Iter 28: Prediction : 19.1278, Weight=1.9215, Error=-0.8722
# Iter 29: Prediction : 19.2150, Weight=1.9293, Error=-0.7850
# Iter 30: Prediction : 19.2935, Weight=1.9364, Error=-0.7065
# Iter 31: Prediction : 19.3641, Weight=1.9428, Error=-0.6359
# Iter 32: Prediction : 19.4277, Weight=1.9485, Error=-0.5723
# Iter 33: Prediction : 19.4849, Weight=1.9536, Error=-0.5151
# Iter 34: Prediction : 19.5365, Weight=1.9583, Error=-0.4635
# Iter 35: Prediction : 19.5828, Weight=1.9625, Error=-0.4172
# Iter 36: Prediction : 19.6245, Weight=1.9662, Error=-0.3755
# Iter 37: Prediction : 19.6621, Weight=1.9696, Error=-0.3379
# Iter 38: Prediction : 19.6959, Weight=1.9726, Error=-0.3041
# Iter 39: Prediction : 19.7263, Weight=1.9754, Error=-0.2737
# Iter 40: Prediction : 19.7537, Weight=1.9778, Error=-0.2463
# Iter 41: Prediction : 19.7783, Weight=1.9800, Error=-0.2217
# Iter 42: Prediction : 19.8005, Weight=1.9820, Error=-0.1995
# Iter 43: Prediction : 19.8204, Weight=1.9838, Error=-0.1796
# Iter 44: Prediction : 19.8384, Weight=1.9855, Error=-0.1616
# Iter 45: Prediction : 19.8545, Weight=1.9869, Error=-0.1455
# Iter 46: Prediction : 19.8691, Weight=1.9882, Error=-0.1309
# Iter 47: Prediction : 19.8822, Weight=1.9894, Error=-0.1178
# Iter 48: Prediction : 19.8940, Weight=1.9905, Error=-0.1060
# Iter 49: Prediction : 19.9046, Weight=1.9914, Error=-0.0954
# Iter 50: Prediction : 19.9141, Weight=1.9923, Error=-0.0859
# Iter 51: Prediction : 19.9227, Weight=1.9930, Error=-0.0773
# Iter 52: Prediction : 19.9304, Weight=1.9937, Error=-0.0696
# Iter 53: Prediction : 19.9374, Weight=1.9944, Error=-0.0626
# Iter 54: Prediction : 19.9436, Weight=1.9949, Error=-0.0564
# Iter 55: Prediction : 19.9493, Weight=1.9954, Error=-0.0507
# Iter 56: Prediction : 19.9544, Weight=1.9959, Error=-0.0456
# Iter 57: Prediction : 19.9589, Weight=1.9963, Error=-0.0411
# Iter 58: Prediction : 19.9630, Weight=1.9967, Error=-0.0370
# Iter 59: Prediction : 19.9667, Weight=1.9970, Error=-0.0333
# Iter 60: Prediction : 19.9700, Weight=1.9973, Error=-0.0300
# Iter 61: Prediction : 19.9730, Weight=1.9976, Error=-0.0270
# Iter 62: Prediction : 19.9757, Weight=1.9978, Error=-0.0243
# Iter 63: Prediction : 19.9782, Weight=1.9980, Error=-0.0218
# Iter 64: Prediction : 19.9803, Weight=1.9982, Error=-0.0197
# Iter 65: Prediction : 19.9823, Weight=1.9984, Error=-0.0177
# Iter 66: Prediction : 19.9841, Weight=1.9986, Error=-0.0159
# Iter 67: Prediction : 19.9857, Weight=1.9987, Error=-0.0143
# Iter 68: Prediction : 19.9871, Weight=1.9988, Error=-0.0129
# Iter 69: Prediction : 19.9884, Weight=1.9990, Error=-0.0116
# Iter 70: Prediction : 19.9896, Weight=1.9991, Error=-0.0104
# Iter 71: Prediction : 19.9906, Weight=1.9992, Error=-0.0094
# Iter 72: Prediction : 19.9915, Weight=1.9992, Error=-0.0085
# Iter 73: Prediction : 19.9924, Weight=1.9993, Error=-0.0076
# Iter 74: Prediction : 19.9931, Weight=1.9994, Error=-0.0069
# Iter 75: Prediction : 19.9938, Weight=1.9994, Error=-0.0062
# Iter 76: Prediction : 19.9945, Weight=1.9995, Error=-0.0055
# Iter 77: Prediction : 19.9950, Weight=1.9996, Error=-0.0050
# Iter 78: Prediction : 19.9955, Weight=1.9996, Error=-0.0045
# Iter 79: Prediction : 19.9960, Weight=1.9996, Error=-0.0040
# Iter 80: Prediction : 19.9964, Weight=1.9997, Error=-0.0036
# Iter 81: Prediction : 19.9967, Weight=1.9997, Error=-0.0033
# Iter 82: Prediction : 19.9971, Weight=1.9997, Error=-0.0029
# Iter 83: Prediction : 19.9973, Weight=1.9998, Error=-0.0027
# Iter 84: Prediction : 19.9976, Weight=1.9998, Error=-0.0024
# Iter 85: Prediction : 19.9978, Weight=1.9998, Error=-0.0022
# Iter 86: Prediction : 19.9981, Weight=1.9998, Error=-0.0019
# Iter 87: Prediction : 19.9983, Weight=1.9998, Error=-0.0017
# Iter 88: Prediction : 19.9984, Weight=1.9999, Error=-0.0016
# Iter 89: Prediction : 19.9986, Weight=1.9999, Error=-0.0014
# Iter 90: Prediction : 19.9987, Weight=1.9999, Error=-0.0013
# Iter 91: Prediction : 19.9989, Weight=1.9999, Error=-0.0011
# Iter 92: Prediction : 19.9990, Weight=1.9999, Error=-0.0010
# Iter 93: Prediction : 19.9991, Weight=1.9999, Error=-0.0009
# Iter 94: Prediction : 19.9992, Weight=1.9999, Error=-0.0008
# Iter 95: Prediction : 19.9993, Weight=1.9999, Error=-0.0007
# Iter 96: Prediction : 19.9993, Weight=1.9999, Error=-0.0007
# Iter 97: Prediction : 19.9994, Weight=1.9999, Error=-0.0006
# Iter 98: Prediction : 19.9995, Weight=2.0000, Error=-0.0005
# Iter 99: Prediction : 19.9995, Weight=2.0000, Error=-0.0005
# Iter 100: Prediction : 19.9996, Weight=2.0000, Error=-0.0004
# Iter 101: Prediction : 19.9996, Weight=2.0000, Error=-0.0004
# Iter 102: Prediction : 19.9996, Weight=2.0000, Error=-0.0004
# Iter 103: Prediction : 19.9997, Weight=2.0000, Error=-0.0003
# Iter 104: Prediction : 19.9997, Weight=2.0000, Error=-0.0003
# Iter 105: Prediction : 19.9997, Weight=2.0000, Error=-0.0003
# Iter 106: Prediction : 19.9998, Weight=2.0000, Error=-0.0002
# Iter 107: Prediction : 19.9998, Weight=2.0000, Error=-0.0002
# Iter 108: Prediction : 19.9998, Weight=2.0000, Error=-0.0002
# Iter 109: Prediction : 19.9998, Weight=2.0000, Error=-0.0002
# Iter 110: Prediction : 19.9998, Weight=2.0000, Error=-0.0002
# Iter 111: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 112: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 113: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 114: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 115: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 116: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 117: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 118: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 119: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 120: Prediction : 19.9999, Weight=2.0000, Error=-0.0001
# Iter 121: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 122: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 123: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 124: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 125: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 126: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 127: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 128: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 129: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 130: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 131: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 132: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 133: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 134: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 135: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Iter 136: Prediction : 20.0000, Weight=2.0000, Error=-0.0000
# Done! It took 136 steps to learn.
