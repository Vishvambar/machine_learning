# %%
import numpy as np

students_dtype = [('Name','U15'),('Marks','i4'),('Attendance','f4')]

students = np.array([
    ('Riya',   88,  92.5),
    ('Aarav',  45,  80.0),
    ('Meera',  76,  85.5),
    ('Ishaan', 95,  90.0),
    ('Kabir',  67,  70.2),
    ('Simran', 82,  88.3),
    ('Tara',   91,  96.5),
    ('Nikhil', 55,  78.4),
    ('Anaya',  98,  94.1),
    ('Dev',    60,  82.6),
    ('Rehan',  73,  89.0),
    ('Karan',  85,  87.2)
], dtype=students_dtype)

# %%
k = 5

# %%
marks  = students['Marks']

# %%
idx = np.argpartition(marks, -k)

# %%
idx
# Out:
# array([ 1,  7,  9,  4, 10,  2,  5, 11,  0,  6,  3,  8])

# %%
marks[idx]
# Out:
# array([45, 55, 60, 67, 73, 76, 82, 85, 88, 91, 95, 98], dtype=int32)
