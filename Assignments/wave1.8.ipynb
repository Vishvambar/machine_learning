# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Sensor_ID": [1, 2, 3, 4, 5],
    "Reading": [98.6, np.nan, 99.1, np.nan, 98.0]
})

# %%
df
# Out:
#    Sensor_ID  Reading
# 0          1     98.6
# 1          2      NaN
# 2          3     99.1
# 3          4      NaN
# 4          5     98.0

# %%
print(df["Reading"].mean())
# Out:
# 98.56666666666666

# %%
df["Reading"] = df["Reading"].fillna(df['Reading'].mean())

# %%
df
# Out:
#    Sensor_ID    Reading
# 0          1  98.600000
# 1          2  98.566667
# 2          3  99.100000
# 3          4  98.566667
# 4          5  98.000000
