# %%
import numpy as np
times = np.array([12.5, 10.1, 9.8, 15.2, 11.0, 9.5, 14.1])

# %%
k = 3 
top3 = np.argpartition(times, k)[:k]

# %%
print(" three fastest times:", times[top3])
# Out:
#  three fastest times: [ 9.5  9.8 10.1]
